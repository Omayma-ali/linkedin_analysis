# %% [markdown]
# # 💼📊 LinkedIn Profiles and Jobs

# %% [markdown]
# <div style="flex:50%; padding:5px;">
#     <img src="linkedin_analysis.jpg">
# </div>

# %% [markdown]
# # 2- 📐Problem Formulations

# %% [markdown]
# ### ❓ Problem  Definition
#     The objective of this assignment is to leverage LinkedIn data to extract valuable insights into professional demographics, career paths, and engagement patterns. By analyzing features such as age, gender, job positions, company sizes, and follower counts

# %% [markdown]
# ### 🚀✨ Solution Approach
#     - Data Loading
#     - Data Cleaning
#         - Handle missing values.
#         - Handling Duplicates
#         - Correct data types for specific columns.
#     - Exploratory Data Analysis (EDA):
#         - Generate descriptive statistics to understand the data distribution.
#         - Analyze categorical and numerical features.
#         - Visualization
#     - Insights Extraction

# %% [markdown]
# ### 🛠️ Tools and Methodology
#     - Programming Language: Python
#     - Libraries:
#         - Pandas: For data manipulation and analysis.
#         - NumPy: For numerical computations.
#         - Matplotlib/Seaborn: For data visualization.
#     - Techniques:
#         - Statistical analysis (mean, median, correlation).
#         - Data filtering and grouping for targeted insights.
#         - Plotting distributions, trends, and relationships.

# %% [markdown]
# # 3. 📥🧹Data Loading and Cleaning

# %% [markdown]
# ### 📚 Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 📂 Loading Data

# %%
df = pd.read_csv("dump.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  ageEstimate  companyFollowerCount  \
# 0           0           41              198859.0
# 1           1           41              198859.0
# 2           2           41               10047.0
# 3           3           41              198859.0
# 4           4           30              300723.0
#
#                                companyHasLogo        companyName  \
# 0  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 1  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 2  b1c3fd9a-8f21-48f8-8321-d773b1ff3cb7-2.png            CommSec
# 3  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 4  0f982557-a907-409e-af20-1feb0e0813cd-2.png             PayPal
#
#    companyStaffCount                   companyUrl           companyUrn  \
# 0            32905.0  http://www.commbank.com.au/  urn:li:company:2848
# 1            32905.0  http://www.commbank.com.au/  urn:li:company:2848
# ...

# %% [markdown]
# ### 🔍 Discovering Data

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ageEstimate', 'companyFollowerCount', 'companyHasLogo',
#        'companyName', 'companyStaffCount', 'companyUrl', 'companyUrn',
#        'connectionsCount', 'country', 'endDate', 'followable',
#        'followersCount', 'genderEstimate', 'hasPicture', 'isPremium',
#        'mbrLocation', 'mbrLocationCode', 'mbrTitle', 'memberUrn',
#        'posLocation', 'posLocationCode', 'posTitle', 'positionId', 'startDate',
#        'avgMemberPosDuration', 'avgCompanyPosDuration'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39537 entries, 0 to 39536
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             39537 non-null  int64
#  1   ageEstimate            39537 non-null  int64
#  2   companyFollowerCount   38071 non-null  float64
#  3   companyHasLogo         36407 non-null  object
#  4   companyName            39535 non-null  object
#  5   companyStaffCount      38401 non-null  float64
#  6   companyUrl             37449 non-null  object
#  7   companyUrn             39537 non-null  object
#  8   connectionsCount       39537 non-null  int64
#  9   country                39537 non-null  object
#  10  endDate                30626 non-null  object
#  11  followable             39537 non-null  int64
#  12  followersCount         39537 non-null  int64
#  13  genderEstimate         35567 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39537 entries, 0 to 39536
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             39537 non-null  int64
#  1   ageEstimate            39537 non-null  int64
#  2   companyFollowerCount   38071 non-null  float64
#  3   companyHasLogo         36407 non-null  object
#  4   companyName            39535 non-null  object
#  5   companyStaffCount      38401 non-null  float64
#  6   companyUrl             37449 non-null  object
#  7   companyUrn             39537 non-null  object
#  8   connectionsCount       39537 non-null  int64
#  9   country                39537 non-null  object
#  10  endDate                30626 non-null  object
#  11  followable             39537 non-null  int64
#  12  followersCount         39537 non-null  int64
#  13  genderEstimate         35567 non-null  object
# ...

# %% [markdown]
# ### 🚫 Missing Values

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# ageEstimate                  0
# companyFollowerCount      1466
# companyHasLogo            3130
# companyName                  2
# companyStaffCount         1136
# companyUrl                2088
# companyUrn                   0
# connectionsCount             0
# country                      0
# endDate                   8911
# followable                   0
# followersCount               0
# genderEstimate            3970
# hasPicture                9936
# isPremium                    0
# mbrLocation                  0
# mbrLocationCode            148
# mbrTitle                     0
# memberUrn                    0
# posLocation              11126
# posLocationCode          22570
# posTitle                     0
# positionId                   0
# startDate                   16
# avgMemberPosDuration       225
# avgCompanyPosDuration      851
# dtype: int64

# %% [markdown]
# ### 🗑️ Dropping Unimportant Columns

# %%
# delete unimportant columns
df = df.drop(['Unnamed: 0', 'posLocationCode', 'posLocation', 'endDate', 'companyHasLogo', 'companyUrn', 'companyUrl', 'mbrLocationCode', 'memberUrn', 'positionId'], axis=1)

# %%
df.shape
# Out:
# (39537, 17)

# %%
df.isna().sum()
# Out:
# ageEstimate                 0
# companyFollowerCount     1466
# companyName                 2
# companyStaffCount        1136
# connectionsCount            0
# country                     0
# followable                  0
# followersCount              0
# genderEstimate           3970
# hasPicture               9936
# isPremium                   0
# mbrLocation                 0
# mbrTitle                    0
# posTitle                    0
# startDate                  16
# avgMemberPosDuration      225
# avgCompanyPosDuration     851
# dtype: int64

# %%
# converting 'haspicture' column to 0 and 1 values
df['hasPicture'].unique()
# Out:
# array([nan, 'RTMZ0-46bTjK4V_MGFDG6i5g0yZmFp5oS0S9liWvpWg.jpg',
#        '7a3eae50-615b-4f5e-bb27-3a5d7fe81acd-3.jpg', ...,
#        'CiYdr4CI882LMWsFYHqTVHYsWZEidja8GpzuzfT75Gg.jpg',
#        '7WKdlBWjnAgosT_iXZ-Yz6QD4sQH9BYlRwBsrhV-464.jpg',
#        'AAEAAQAAAAAAAAyLAAAAJDRlYTllMDA5LWI0NTItNDczNS04YjVkLWUzMGM5NjM2NGY3ZA.jpg'],
#       dtype=object)

# %%
# if the profile has picture then put 1 else put 0
df['hasPicture'] = df['hasPicture'].apply(lambda x : 1 if pd.notna(x) else 0)

# %%
df['hasPicture'].value_counts()
# Out:
# 1    29601
# 0     9936
# Name: hasPicture, dtype: int64

# %%
df.isna().sum()
# Out:
# ageEstimate                 0
# companyFollowerCount     1466
# companyName                 2
# companyStaffCount        1136
# connectionsCount            0
# country                     0
# followable                  0
# followersCount              0
# genderEstimate           3970
# hasPicture                  0
# isPremium                   0
# mbrLocation                 0
# mbrTitle                    0
# posTitle                    0
# startDate                  16
# avgMemberPosDuration      225
# avgCompanyPosDuration     851
# dtype: int64

# %%
# drop missing values for the remaining column
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# ageEstimate              0
# companyFollowerCount     0
# companyName              0
# companyStaffCount        0
# connectionsCount         0
# country                  0
# followable               0
# followersCount           0
# genderEstimate           0
# hasPicture               0
# isPremium                0
# mbrLocation              0
# mbrTitle                 0
# posTitle                 0
# startDate                0
# avgMemberPosDuration     0
# avgCompanyPosDuration    0
# dtype: int64

# %%
# shape after drop the missing values
df.shape
# Out:
# (33514, 17)

# %%
# Correct data types for columns
df['companyFollowerCount'] = df['companyFollowerCount'].astype(int)
df['companyStaffCount'] = df['companyStaffCount'].astype(int)
df['avgMemberPosDuration'] = df['avgMemberPosDuration'].astype(int)
df['avgCompanyPosDuration'] = df['avgCompanyPosDuration'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33514 entries, 0 to 39536
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ageEstimate            33514 non-null  int64
#  1   companyFollowerCount   33514 non-null  int32
#  2   companyName            33514 non-null  object
#  3   companyStaffCount      33514 non-null  int32
#  4   connectionsCount       33514 non-null  int64
#  5   country                33514 non-null  object
#  6   followable             33514 non-null  int64
#  7   followersCount         33514 non-null  int64
#  8   genderEstimate         33514 non-null  object
#  9   hasPicture             33514 non-null  int64
#  10  isPremium              33514 non-null  int64
#  11  mbrLocation            33514 non-null  object
#  12  mbrTitle               33514 non-null  object
#  13  posTitle               33514 non-null  object
# ...

# %% [markdown]
# ### 🔄 Duplicates

# %%
# check duplicates
df.duplicated().sum()
# Out:
# 86

# %% [markdown]
# #  4- 📈 Descriptive Statistics

# %% [markdown]
# ### ⭕ Categorical Columns

# %%
# Select only the Categorical columns
categorical_data = df.select_dtypes(include=['object'])

# %%
categorical_data
# Out:
#                        companyName country genderEstimate  \
# 0                Commonwealth Bank      au           male
# 1                Commonwealth Bank      au           male
# 2                          CommSec      au           male
# 3                Commonwealth Bank      au           male
# 4                           PayPal      au         female
# ...                            ...     ...            ...
# 39532           Lifeline Australia      au         female
# 39533  Wingham Brush Public School      au         female
# 39534            Commonwealth Bank      au         female
# 39535      Standard Chartered Bank      au         female
# 39536                          ANZ      au         female
#
#                       mbrLocation  \
# 0          Sydney Area, Australia
# 1          Sydney Area, Australia
# 2          Sydney Area, Australia
# 3          Sydney Area, Australia
# 4          Sydney Area, Australia
# ...                           ...
# ...

# %%
categorical_data.describe()
# Out:
#        companyName country genderEstimate        mbrLocation  \
# count        33514   33514          33514              33514
# unique       11051       1              2                436
# top        Telstra      au           male  Sydney, Australia
# freq           612   33514          22432               7696
#
#                                                  mbrTitle         posTitle  \
# count                                               33514            33514
# unique                                               5913            20801
# top     National Coordinator - Website and Learning Ma...  Project Manager
# freq                                                   58              383
#
#        startDate
# count      33514
# unique       463
# top     1/1/2012
# freq         432

# %% [markdown]
# ## 📝 Interpretation of Results
#     1- Company Names: The dataset includes 11,051 unique companies, with Telstra being the most common, representing 612 profiles.
#     2- Country: All profiles are from Australia (AU).
#     3- Gender: 67% of the profiles are male.
#     4- Location: There are 436 unique locations, with Sydney, Australia being the most common, appearing in 7,696 profiles.
#     5- Member Title: There are 5,913 unique member titles, with the most frequent being National Coordinator - Website and Learning Management (appearing 58 times).
#     6- Position Title: The most common position title is Project Manager, found in 383 profiles out of 20,801 unique titles.
#     7- Start Date: The most frequent job start date is January 1, 2012, appearing in 432 profiles.

# %% [markdown]
# ### 🔢 Numerical Columns

# %%
# Select only the numerical columns
numerical_data = df.select_dtypes(include=['float64', 'int64'])

# %%
numerical_data
# Out:
#        ageEstimate  connectionsCount  followable  followersCount  hasPicture  \
# 0               41               500           1             506           0
# 1               41               500           1             506           0
# 2               41               500           1             506           0
# 3               41               500           1             506           0
# 4               30               500           1             951           1
# ...            ...               ...         ...             ...         ...
# 39532           30                 2           1               3           0
# 39533           30                 2           1               3           0
# 39534           39                 0           1               0           0
# 39535           39                 0           1               0           0
# 39536           39                 0           1               0           0
#
#        isPremium
# 0              0
# ...

# %%
numerical_data.describe()
# Out:
#         ageEstimate  connectionsCount    followable  followersCount  \
# count  33514.000000      33514.000000  33514.000000    33514.000000
# mean      38.594080        425.210449      0.950200     1163.600645
# std        9.602225        121.853117      0.217535     2893.599779
# min       20.000000          0.000000      0.000000        0.000000
# 25%       31.000000        372.000000      1.000000      354.000000
# 50%       38.000000        500.000000      1.000000      650.000000
# 75%       45.000000        500.000000      1.000000     1179.000000
# max       82.000000        500.000000      1.000000   161922.000000
#
#          hasPicture     isPremium
# count  33514.000000  33514.000000
# mean       0.748016      0.130721
# std        0.434159      0.337101
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      0.000000
# max        1.000000      1.000000

# %%
# Create subplots
plt.figure(figsize=(15, 10))

# Boxplot for ageEstimate
plt.subplot(2, 2, 1) 
sns.boxplot(y=df['ageEstimate'])
plt.title('Boxplot of Age Estimate')
plt.ylabel('Age Estimate')

# Boxplot for connectionsCount
plt.subplot(2, 2, 2)  
sns.boxplot(y=df['connectionsCount'])
plt.title('Boxplot of Connections Count')
plt.ylabel('Connections Count')

# Boxplot for followersCount
plt.subplot(2, 2, 3)  
sns.boxplot(y=df['followersCount'])
plt.title('Boxplot of Followers Count')
plt.ylabel('Followers Count')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📝 Interpretation of Results
#     1- Age: Members ages range from 20 to 82, with an average of 39 years. Half of the members are aged 38 or below.
#     2- Connections: Most members have 500 connections, with an average of 425 connections.
#     3- Followers: The average number of followers is 1,163, but this varies significantly, with a maximum of 161,922 followers.
#     4- Followable: 95% of members have followability enabled.
#     5- Profile Picture: 74% of members have a profile picture.
#     6- Premium Account: Only 13% of members have a premium LinkedIn account.

# %% [markdown]
# # 5- 📊 Data Visualization

# %%
# Correlation Matrix
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\CM\AppData\Local\Temp\ipykernel_2228\584861638.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm', square=True, cbar_kws={"shrink": .8})

# %%
# Pairplot
plt.figure(figsize=(12, 20))
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='genderEstimate', data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
gender_distribution = df['genderEstimate'].value_counts(normalize=True) * 100
print(f'Gender distribution: {gender_distribution.to_dict()}')
# Out:
# Gender distribution: {'male': 66.93322193710091, 'female': 33.06677806289909}

# %%
# positions frequency
position_counts = df['posTitle'].value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=position_counts.index, y=position_counts.values)
plt.title('Top 10 Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Number of Members')
plt.xticks(rotation=45)
plt.show()

# %%
# Most popular companies
top_companies = df['companyName'].value_counts().head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_companies.index, y=top_companies.values)
plt.title('Top 10 Companies by Number of Members')
plt.xlabel('Company Name')
plt.ylabel('Number of Members')
plt.xticks(rotation=45)
plt.show()

# %%
# Follower Age Frequency
plt.figure(figsize=(10, 6))
sns.histplot(df['ageEstimate'], kde=True)
plt.title('Distribution of Followers Age')
plt.xlabel('Follower Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Age analysis
avg_age = df['ageEstimate'].mean()
print(f'The average age of members is approximately {avg_age:.2f} years.')
# Out:
# The average age of members is approximately 38.59 years.

# %%
top_companies = df.groupby('companyName')['companyStaffCount'].max().sort_values(ascending=False).head(10).reset_index()
# Number of Staff in Top 10 Companies
plt.figure(figsize=(10, 6))
sns.barplot(x='companyName', y='companyStaffCount', data=top_companies, palette='viridis')
plt.title('Number of Staff in Top 10 Companies')
plt.xlabel('Company Name')
plt.ylabel('Number of Staff')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()  
plt.show()

# %%
largest_company_count = df['companyStaffCount'].max()
largest_company = df.loc[df['companyStaffCount'].idxmax(), 'companyName']
print(f'The largest company in the dataset is {largest_company} with {largest_company_count} employees.')
# Out:
# The largest company in the dataset is IBM with 568533 employees.

# %%
premium_members = df[df['isPremium'] == 1].shape[0]
total_members = df.shape[0]
non_premium_members = total_members - premium_members
premium_percentage = (premium_members / total_members) * 100

# Percentage of Premium Members
plt.figure(figsize=(6, 6))
labels = ['Premium Members', 'Non-Premium Members']
sizes = [premium_members, non_premium_members]
colors = ['#4CAF50', '#FFC107']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=[0.1, 0])
plt.title('Percentage of Premium Members')
plt.show()

# %%
average_followers =  df.groupby('companyName')['followersCount'].mean().sort_values(ascending=False).head(10).reset_index()

# Average Number of Followers foreach company
plt.figure(figsize=(10, 6))
sns.barplot(x='companyName', y='followersCount',data=average_followers, palette='Blues_r')
plt.title('Average Number of Followers per company')
plt.xlabel('Company Name')
plt.ylabel('followersCount')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()  
plt.show()

# %%
# Relationship between Connections and Followers
plt.figure(figsize=(8, 6))
sns.scatterplot(x='connectionsCount', y='followersCount', data=df, color='#FF5733', alpha=0.6)
sns.regplot(x='connectionsCount', y='followersCount', data=df, scatter=False, color='blue', line_kws={'linewidth': 2})
plt.title(f'Relationship between Connections and Followers')
plt.xlabel('Connections Count')
plt.ylabel('Followers Count')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df['startDate'] = pd.to_datetime(df['startDate'])
df['year'] = df['startDate'].dt.year
yearly_counts = df['year'].value_counts().sort_index()
yearly_counts.plot(kind='bar', color='darkorange')
plt.title('Number of Positions Started Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Positions')
plt.show()

# %%
most_active_year = yearly_counts.idxmax()
most_active_year_count = yearly_counts.max()
print(f'The most active year for new positions was {most_active_year} with {most_active_year_count} positions started.')
# Out:
# The most active year for new positions was 2016 with 2968 positions started.

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df['avgMemberPosDuration'], label='Avg Member Position Duration', color='red')
sns.kdeplot(df['avgCompanyPosDuration'], label='Avg Company Position Duration', color='blue')
plt.title('Distribution of Position Durations (Member vs. Company)')
plt.legend()
plt.show()

# %%
# Position duration analysis
avg_member_duration = df['avgMemberPosDuration'].mean()
avg_company_duration = df['avgCompanyPosDuration'].mean()
print(f'The average position duration for members is {avg_member_duration:.2f} months,\nwhile the average position duration for companies is {avg_company_duration:.2f} months.')
# Out:
# The average position duration for members is 884.09 months,
# while the average position duration for companies is 890.86 months.

# %%
top_10_companies = df['companyName'].value_counts().head(10).index
df_top_companies = df[df['companyName'].isin(top_10_companies)]

# Age vs. CompanyName (Scatter Plot)
plt.figure(figsize=(10, 6))  
sns.scatterplot(y='ageEstimate', x='companyName', hue='genderEstimate', data=df_top_companies, palette='coolwarm', s=100, alpha=0.7)
plt.title('Age vs. Company Name (Colored by Gender)')
plt.xlabel('Company Name')
plt.ylabel('Age Estimate')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6- 📄✅ Final Report:

# %% [markdown]
# ### 1️⃣ **Data Acquisition**
# The data was acquired from LinkedIn profile exports, which include member details, job positions, and engagement metrics. The dataset contains **33,514 entries** with key variables like **age, connections, followers, company, location, and position details**.
#
# ---
#
# ### 2️⃣ **Data Cleaning Process**
# - **Missing Data Handling**: Ensured no null values existed as all fields were fully populated.
# - **Data Type Conversion**: Converted **startDate** to a date format and **categorical columns** (like company, gender, and location) to appropriate data types.
# - **Outlier Detection**: Identified and flagged extreme values, particularly in **followersCount**, where a maximum of **161,922 followers** was an outlier relative to the median of **650**.
# - **Duplicate Removal**: Checked and removed potential duplicate profiles.
#
# ---
#
# ### 3️⃣ **Key Insights from Descriptive Statistics and Visualizations**
# **A. Demographics**
# - **Age**: Members are aged **20 to 82**, with an average of **39 years**, reflecting a mid-career demographic.
# - **Gender**: The dataset is **67% male** and **33% female**, indicating a gender imbalance.
# - **Location**: The majority of members are located in **Sydney, Australia** (23% of profiles).
#
# **B. Professional Insights**
# - **Company Representation**: There are **11,051 unique companies**, with **Telstra** being the most represented, appearing in **612 profiles**.
# - **Job Roles**: The most common position is **Project Manager**, found in **383 profiles**, while the most frequent member title is **National Coordinator - Website and Learning Management**.
#
# **C. Engagement & Activity**
# - **Connections**: Most members have the **500 connection limit**, indicating strong network-building activity.
# - **Followers**: Members have an average of **1,163 followers**, but this is skewed by outliers like the maximum of **161,922 followers**.
# - **Profile Completeness**: **74% of members** have a profile picture, and **95%** have enabled the follow feature.
# - **Premium Users**: Only **13% of members** use a premium LinkedIn account, suggesting limited adoption of paid subscriptions.
#
# **D. Time-Based Insights**
# - **Start Date**: The most frequent job start date is **January 1, 2012**, with significant hiring activity observed around this date.
#
# ---
#
# ### 4️⃣ **Conclusion**
# This analysis provided valuable insights into LinkedIn profile demographics, professional roles, and engagement behavior. The findings reveal a large presence of experienced, mid-career professionals, especially **project managers** and **coordinators** working at major companies like **Telstra**. Most users prioritize visibility, as seen from the high rate of **profile pictures** and **followable accounts**, but only a small portion subscribes to **LinkedIn Premium**. The analysis highlights key areas where professionals aim to boost visibility, like maximizing connections and engaging with followers. This exploration demonstrates the power of **data-driven career analysis** to understand career trajectories, popular roles, and networking strategies on LinkedIn.
